# %%
# @hidden_cell
# The following code contains the credentials for a file in your IBM Cloud Object Storage.
# You might want to remove those credentials before you share your notebook.
credentials_1 = {
    'IAM_SERVICE_ID': 'iam-ServiceId-46f17057-00da-4400-9f59-20947176e573',
    'IBM_API_KEY_ID': 'IUhS2Bg4IJTyeylFWeUp8AdIHrMSYkvJo_NTlsD08y36',
    'ENDPOINT': 'https://s3-api.us-geo.objectstorage.service.networklayer.com',
    'IBM_AUTH_ENDPOINT': 'https://iam.cloud.ibm.com/oidc/token',
    'BUCKET': 'shopifychallenge-donotdelete-pr-lch67hbzrhpsok',
    'FILE': '2019 Winter Data Science Intern Challenge Data Set.csv'
}
import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

if os.environ.get('RUNTIME_ENV_LOCATION_TYPE') == 'external':
    endpoint_9b936849da084a469c3d767cc8bfbae3 = 'https://s3-api.us-geo.objectstorage.softlayer.net'
else:
    endpoint_9b936849da084a469c3d767cc8bfbae3 = 'https://s3-api.us-geo.objectstorage.service.networklayer.com'

client_9b936849da084a469c3d767cc8bfbae3 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='IUhS2Bg4IJTyeylFWeUp8AdIHrMSYkvJo_NTlsD08y36',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url=endpoint_9b936849da084a469c3d767cc8bfbae3)

body = client_9b936849da084a469c3d767cc8bfbae3.get_object(Bucket='shopifychallenge-donotdelete-pr-lch67hbzrhpsok',Key='2019 Winter Data Science Intern Challenge Data Set.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_1 = pd.read_csv(body)
df_data_1.head()
# Out:
#    order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0       1.0     53.0    746.0         224.0          2.0           cash
# 1       2.0     92.0    925.0          90.0          1.0           cash
# 2       3.0     44.0    861.0         144.0          1.0           cash
# 3       4.0     18.0    935.0         156.0          1.0    credit_card
# 4       5.0     18.0    883.0         156.0          1.0    credit_card
#
#             created_at
# 0  2017-03-13 12:36:56
# 1  2017-03-03 17:38:52
# 2   2017-03-14 4:23:56
# 3  2017-03-26 12:43:37
# 4   2017-03-01 4:35:11

# %%
import numpy as np  
import pandas as pd

# %%
df_data_1.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5001 entries, 0 to 5000
# Columns: 7 entries, order_id to created_at
# dtypes: float64(5), object(2)
# memory usage: 273.6+ KB

# %%
df_data_1[["order_amount"]].mean() # calculate the mean of order_amount
# Out:
# order_amount    3145.128
# dtype: float64

# %%
df_data_1.dropna(axis=0, how='any', thresh=None, subset=None, inplace=True)
df_data_1.tail()
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 4995    4996.0     73.0    993.0         330.0          2.0          debit
# 4996    4997.0     48.0    789.0         234.0          2.0           cash
# 4997    4998.0     56.0    867.0         351.0          3.0           cash
# 4998    4999.0     60.0    825.0         354.0          2.0    credit_card
# 4999    5000.0     44.0    734.0         288.0          2.0          debit
#
#                created_at
# 4995  2017-03-30 13:47:17
# 4996  2017-03-16 20:36:16
# 4997   2017-03-19 5:42:42
# 4998  2017-03-16 14:51:18
# 4999  2017-03-18 15:48:18

# %%
df_data_1["order_value_per_item"]=df_data_1["order_amount"]/df_data_1["total_items"] # add a new column to the dataframe to get order value per item.

# %%
df_data_1.head() # Now a column order_value_per_item was added to the dataframe.
# Out:
#    order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0       1.0     53.0    746.0         224.0          2.0           cash
# 1       2.0     92.0    925.0          90.0          1.0           cash
# 2       3.0     44.0    861.0         144.0          1.0           cash
# 3       4.0     18.0    935.0         156.0          1.0    credit_card
# 4       5.0     18.0    883.0         156.0          1.0    credit_card
#
#             created_at  order_value_per_item
# 0  2017-03-13 12:36:56                 112.0
# 1  2017-03-03 17:38:52                  90.0
# 2   2017-03-14 4:23:56                 144.0
# 3  2017-03-26 12:43:37                 156.0
# 4   2017-03-01 4:35:11                 156.0

# %%
df2=df_data_1.groupby('shop_id').sum()[['order_amount']]
df2.head()
df2.sort_values(by=['order_amount'],inplace=True,ascending=False)
df2.head(10)
# Out:
#          order_amount
# shop_id
# 42.0       11990176.0
# 78.0        2263800.0
# 89.0          23128.0
# 81.0          22656.0
# 6.0           22627.0
# 13.0          21760.0
# 59.0          21538.0
# 71.0          21320.0
# 19.0          20538.0
# 70.0          20241.0

# %%
df3=df_data_1.groupby('shop_id').mean()[['order_value_per_item']]
df3.head()
df3.sort_values(by=['order_value_per_item'],inplace=True,ascending=False)
df3.head(10)
# Out:
#          order_value_per_item
# shop_id
# 78.0                  25725.0
# 42.0                    352.0
# 12.0                    201.0
# 89.0                    196.0
# 99.0                    195.0
# 50.0                    193.0
# 38.0                    190.0
# 51.0                    187.0
# 6.0                     187.0
# 11.0                    184.0

# %%
df_data_1[['order_value_per_item']].mean()
# Out:
# order_value_per_item    387.7428
# dtype: float64

# %%
df_data_1[df_data_1['shop_id']==78.0]
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 160      161.0     78.0    990.0       25725.0          1.0    credit_card
# 490      491.0     78.0    936.0       51450.0          2.0          debit
# 493      494.0     78.0    983.0       51450.0          2.0           cash
# 511      512.0     78.0    967.0       51450.0          2.0           cash
# 617      618.0     78.0    760.0       51450.0          2.0           cash
# 691      692.0     78.0    878.0      154350.0          6.0          debit
# 1056    1057.0     78.0    800.0       25725.0          1.0          debit
# 1193    1194.0     78.0    944.0       25725.0          1.0          debit
# 1204    1205.0     78.0    970.0       25725.0          1.0    credit_card
# 1259    1260.0     78.0    775.0       77175.0          3.0    credit_card
# 1384    1385.0     78.0    867.0       25725.0          1.0           cash
# ...

# %%
df4=df_data_1[df_data_1['shop_id']!=78.0]
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4954 entries, 0 to 4999
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   order_id              4954 non-null   float64
#  1   shop_id               4954 non-null   float64
#  2   user_id               4954 non-null   float64
#  3   order_amount          4954 non-null   float64
#  4   total_items           4954 non-null   float64
#  5   payment_method        4954 non-null   object
#  6   created_at            4954 non-null   object
#  7   order_value_per_item  4954 non-null   float64
# dtypes: float64(6), object(2)
# memory usage: 348.3+ KB

# %%
df4[['order_value_per_item']].mean()
# Out:
# order_value_per_item    152.475575
# dtype: float64
